# %% [markdown]
# # NeuroAds - RunPod Deployment Guide
# This notebook will set up the environment and run the NeuroAds Flask application on RunPod.

# %%
# 1. Install System Dependencies
# !apt-get update && apt-get install -y ffmpeg libsm6 libxext6

# %%
# 2. Install Python Requirements
# !pip install -r requirements.txt
# !pip install "tribev2[plotting] @ git+https://github.com/facebookresearch/tribev2.git"

# %%
# 3. Run the Application
# Note: RunPod uses port 5000 by default for HTTP traffic if using the HTTP proxy.
# !python app.py

# %% [markdown]
# ### Accessing the App
# Once the server starts, you can access it via the RunPod proxy URL:
# `https://{YOUR_POD_ID}-5000.proxy.runpod.net/`
